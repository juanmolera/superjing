# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %% [markdown]
# ##### Libraries and configuration

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Load files

# %%
df_train = pd.read_excel('DSC_training.xlsx')
print(df_train.shape)
df_train.head(1)
# Out:
# (7638, 175)
#    ACTIVE_CREDITS_FLG  APPLICANTS_CNT APPLICATION_BY_EMPLOYEE_FLG  \
# 0                 1.0               1                           N
#
#   APPLICATION_DT  APPLIED_AMT  COLLATERAL_AMT  \
# 0     2018-03-02       4777.8             0.0
#
#    CREDIT_INTER_PRIV_PERIODIC_MTHS  CREDIT_INTER_PROF_PERIODIC_MTHS  \
# 0                              1.0                             12.0
#
#    DEBET_INTER_PRIV_PERIODIC_MTHS  DEBET_INTER_PROF_PERIODIC_MTHS  \
# 0                             1.0                            12.0
#
#    EXP_WITH_CUSTOMER_CD  EXST_CHRG_PRFCRED_AMT FINANCIAL_PRODUCT_TYPE_CD  \
# 0                     1               11400.67                       MTG
#
#    KPI_CASH_FLOW_AMT  KPI_REPAYM_CAP_AMT  LOAN_TO_VALUE_PCT  LOSS_YEAR_AMT  \
# 0           28265.09            11719.07                0.0            0.0
#
#   MATURITY_DT  MORTGAGE_ON_REAL_ESTATE_FLG  MTHS_IN_BUSINESS_CNT  \
# 0  2019-03-20                          1.0                   NaN
#
#    OTH_BANKS_CREDITS_AMT  OTHER_CREDITS_CNT  PROFIT_BEFORE_TAX_AMT  \
# 0                      0                  0               21260.97
#
#    REAL_ESTATE_VALUE_AMT  TOT_OPEN_CREDITS_AMT  WRITE_OFF_YEAR_AMT  \
# 0                    NaN              11400.67             7004.12
#
#   CREDIT_TYPE_CD  ANNUAL_INCOME_AMT_avg  AVG_NEG_SALDO_PRIV_12_AMT_max  \
# 0             IK               17046.12                       126.0375
#
#    AVG_NEG_SALDO_PRIV_1_AMT_max  AVG_NEG_SALDO_PRIV_24_AMT_max  \
# 0                           0.0                     113.802708
#
#    AVG_NEG_SALDO_PRIV_3_AMT_max  AVG_NEG_SALDO_PRIV_6_AMT_max  \
# 0                     50.318333                    113.386667
#
#    AVG_NEG_SALDO_PRIV_9_AMT_max  AVG_NEG_SALDO_PROF_12_AMT_max  \
# 0                    133.838889                      21.646667
#
#    AVG_NEG_SALDO_PROF_1_AMT_max  AVG_NEG_SALDO_PROF_24_AMT_max  \
# 0                           0.0                      15.853333
#
#    AVG_NEG_SALDO_PROF_3_AMT_max  AVG_NEG_SALDO_PROF_6_AMT_max  \
# 0                      5.236667                     12.126667
#
#    AVG_NEG_SALDO_PROF_9_AMT_max  AVG_POS_SALDO_PRIV_12_AMT_avg  \
# 0                     17.233333                      2649.0425
#
#    AVG_POS_SALDO_PRIV_1_AMT_avg  AVG_POS_SALDO_PRIV_24_AMT_avg  \
# 0                       2107.41                    1586.087292
#
#    AVG_POS_SALDO_PRIV_3_AMT_avg  AVG_POS_SALDO_PRIV_6_AMT_avg  \
# 0                   2233.248333                   2422.888333
#
#    AVG_POS_SALDO_PRIV_9_AMT_avg  AVG_POS_SALDO_PROF_12_AMT_avg  \
# 0                       2544.91                    2143.520833
#
#    AVG_POS_SALDO_PROF_1_AMT_avg  AVG_POS_SALDO_PROF_24_AMT_avg  \
# 0                        2020.3                    2488.447083
#
#    AVG_POS_SALDO_PROF_3_AMT_avg  AVG_POS_SALDO_PROF_6_AMT_avg  \
# 0                   1966.703333                   1907.106667
#
#    AVG_POS_SALDO_PROF_9_AMT_avg  AVG_POS_SALDO_SAVINGS_12_AMT_avg  \
# 0                   1957.008889                               NaN
#
#    AVG_POS_SALDO_SAVINGS_1_AMT_avg  AVG_POS_SALDO_SAVINGS_24_AMT_avg  \
# 0                              NaN                               NaN
#
#    AVG_POS_SALDO_SAVINGS_3_AMT_avg  AVG_POS_SALDO_SAVINGS_6_AMT_avg  \
# 0                              NaN                              NaN
#
#    AVG_POS_SALDO_SAVINGS_9_AMT_avg  DEPENDENTS_CNT_max CAT_EDUCATION_LEVEL_CD  \
# 0                              NaN                 0.0                      3
#
#   EMPLOYMENT_STATUS_CD       PROFESSION_CAT COMB_MARITAL_STATUS  \
# 0                  410  ANDERE-ZELFSTANDIGE                  01
#
#    MONTHLY_ALIMONY_CHARGES_AMT_max  MONTHLY_CHILD_ALLOWANCE_AMT_avg  \
# 0                              0.0                              0.0
#
#    MONTHLY_FOREIGN_INCOME_AMT_avg  MONTHLY_HOUSING_AMT_max  \
# 0                             0.0                 11400.67
#
#    MONTHLY_OTHER_CHARGES_AMT_max  MONTHLY_OTHER_INCOME_AMT_avg  \
# 0                            0.0                           0.0
#
#    MONTHLY_RENTAL_CHARGES_AMT_max  MONTHLY_REPL_INCOME_AMT_avg  \
# 0                             0.0                          0.0
#
#   CAT_INCOME_SRC_CD  MONTHS_CURRENT_ADDR_CNT_min  MONTHS_IN_BELGIUM_CNT_min  \
# 0               NaN                        218.0                        NaN
#
#    NO_CREDIT_CARDS_COREPRIV_CNT_max  NO_CREDIT_CARDS_COREPROF_CNT_max  \
# 0                               0.0                               0.0
#
#    NO_DAYS_CRED_MIN500_PRIV_CNT_avg  NO_DAYS_CRED_MIN500_PROF_CNT_avg  \
# 0                              11.0                              12.0
#
#    NO_DAYS_CRED_MIN500_SAVE_CNT_avg  NO_DAYS_DEBT_MIN500_PRIV_CNT_avg  \
# 0                               NaN                               5.0
#
#    NO_DAYS_DEBT_MIN500_PROF_CNT_avg  NO_DAYS_DEBT_MIN500_SAVE_CNT_avg  \
# 0                               8.0                               NaN
#
#    NO_DEBET_CARDS_COREPRIV_CNT_max  NO_DEBET_CARDS_COREPROF_CNT_max  \
# 0                              1.0                              1.0
#
#    OTH_BANKS_CREDITS_AMT_max  OTHER_REAL_ESTATE_FLG_max  \
# 0                          0                        1.0
#
#    OVERDRAWN_DAYS_PRIV_1_CNT_max  OVERDRAWN_DAYS_PRIV_3_CNT_max  \
# 0                            0.0                            0.0
#
#    OVERDRAWN_DAYS_PRIV_6_CNT_max  OVERDRAWN_DAYS_PRIV_9_CNT_max  \
# 0                            0.0                            0.0
#
#    OVERDRAWN_DAYS_PRIV_12_CNT_max  OVERDRAWN_DAYS_PRIV_24_CNT_max  \
# 0                             0.0                            28.0
#
#    OVERDRAWN_DAYS_PROF_1_CNT_max  OVERDRAWN_DAYS_PROF_3_CNT_max  \
# 0                            0.0                            0.0
#
#    OVERDRAWN_DAYS_PROF_6_CNT_max  OVERDRAWN_DAYS_PROF_9_CNT_max  \
# 0                            0.0                            0.0
#
#    OVERDRAWN_DAYS_PROF_12_CNT_max  OVERDRAWN_DAYS_PROF_24_CNT_max  \
# 0                             0.0                             0.0
#
#    POSIT_TRANS_COREPRIV_CNT_avg  POSIT_TRANS_COREPROF_CNT_avg  \
# 0                           4.0                           3.0
#
#    POSIT_TRANS_SAVINGS_CNT_avg CAT_REP_INCOME_SRC_CD CAT_RESIDENT_STATUS_CD  \
# 0                          NaN                   NaN                      1
#
#    SAVINGS_OPEN_CNT_max  TOT_CRE_INTEREST_PRIV_1_AMT_max  \
# 0                   NaN                              0.0
#
#    TOT_CRE_INTEREST_PRIV_3_AMT_max  TOT_CRE_INTEREST_PRIV_6_AMT_max  \
# 0                              0.0                              0.0
#
#    TOT_CRE_INTEREST_PRIV_9_AMT_max  TOT_CRE_INTEREST_PRIV_12_AMT_max  \
# 0                              0.0                               0.0
#
#    TOT_CRE_INTEREST_PRIV_24_AMT_max  TOT_CRE_INTEREST_PROF_1_AMT_max  \
# 0                               0.0                              0.0
#
#    TOT_CRE_INTEREST_PROF_3_AMT_max  TOT_CRE_INTEREST_PROF_6_AMT_max  \
# 0                              0.0                              0.0
#
#    TOT_CRE_INTEREST_PROF_9_AMT_max  TOT_CRE_INTEREST_PROF_12_AMT_max  \
# 0                              0.0                               0.0
#
#    TOT_CRE_INTEREST_PROF_24_AMT_max  TOT_CRED_LINE_COREPRIV_AMT_max  \
# 0                               0.0                          1250.0
#
#    TOT_CRED_LINE_COREPROF_AMT_max  TOT_DEB_INTEREST_PRIV_1_AMT_max  \
# 0                             0.0                              0.0
#
#    TOT_DEB_INTEREST_PRIV_3_AMT_max  TOT_DEB_INTEREST_PRIV_6_AMT_max  \
# 0                             27.5                           107.42
#
#    TOT_DEB_INTEREST_PRIV_9_AMT_max  TOT_DEB_INTEREST_PRIV_12_AMT_max  \
# 0                           163.15                            182.47
#
#    TOT_DEB_INTEREST_PRIV_24_AMT_max  TOT_DEB_INTEREST_PROF_1_AMT_max  \
# 0                            307.23                              0.0
#
#    TOT_DEB_INTEREST_PROF_3_AMT_max  TOT_DEB_INTEREST_PROF_6_AMT_max  \
# 0                             2.91                            11.64
#
#    TOT_DEB_INTEREST_PROF_9_AMT_max  TOT_DEB_INTEREST_PROF_12_AMT_max  \
# 0                            20.37                             26.74
#
#    TOT_DEB_INTEREST_PROF_24_AMT_max  TOT_DOM_EXC_CRE_EXT_PRIV_AMT_max  \
# 0                             36.15                               0.0
#
#    TOT_DOM_EXC_CRE_EXT_PRIV_CNT_max  TOT_DOM_EXC_CRE_EXT_PROF_AMT_max  \
# 0                               0.0                              54.0
#
#    TOT_DOM_EXC_CRE_EXT_PROF_CNT_max  TOT_DOM_EXC_CRE_INT_PRIV_AMT_max  \
# 0                               1.0                               NaN
#
#    TOT_DOM_EXC_CRE_INT_PRIV_CNT_max  TOT_DOM_EXC_CRE_INT_PROF_AMT_max  \
# 0                               NaN                               NaN
#
#    TOT_DOM_EXC_CRE_INT_PROF_CNT_max  TOT_DOMIC_CREDCD_COREPRIV_AMT_MX  \
# 0                               NaN                               NaN
#
#    TOT_DOMIC_CREDCD_COREPROF_AMT_MX  TOT_OPEN_CREDITS_AMT_max  \
# 0                               NaN                  11400.67
#
#    TOT_STND_PAYMENT_EXT_PRIV_AMT_MX  TOT_STND_PAYMENT_EXT_PROF_AMT_MX  \
# 0                               0.0                              30.0
#
#    TOT_STND_PAYMENT_INT_PRIV_AMT_MX  TOT_STND_PAYMENT_INT_PROF_AMT_MX  \
# 0                               0.0                               0.0
#
#    TOT_STND_PAYMNT_EXT_PRIV_CNT_MX  TOT_STND_PAYMNT_EXT_PROF_CNT_MX  \
# 0                              0.0                              1.0
#
#    TOT_STND_PAYMNT_INT_PRIV_CNT_MX  TOT_STND_PAYMNT_INT_PROF_CNT_MX  \
# 0                              0.0                              0.0
#
#    TOTAL_EMPLOYMENT_MONTHS_CNT_min  TTL_EMPLOYMENT_MONTHS_2_CNT_min  \
# 0                            218.0                            218.0
#
#    NR_APPLICANTS_WITH_INCOME  BEH_SCORE_AVG_A1  BEH_SCORE_MIN_A1  \
# 0                          1               NaN               NaN
#
#    BEH_SCORE_AVG_A2  BEH_SCORE_MIN_A2  BEH_SCORE_AVG_A3  BEH_SCORE_MIN_A3  \
# 0               NaN               NaN               NaN               NaN
#
#    BEH_SCORE_AVG_AVG  BEH_SCORE_AVG_MIN  BEH_SCORE_MIN_AVG  BEH_SCORE_MIN_MIN  \
# 0                NaN                NaN                NaN                NaN
#
#    Gender_A1  Gender_A2  Gender_A3 nationality_A1 nationality_A2  \
# 0        1.0        NaN        NaN              B            NaN
#
#   nationality_A3  Nace_A1  year  birth_dt_A1  birth_dt_A2  birth_dt_A3  \
# 0            NaN  47299.0  2018         1973          NaN          NaN
#
#    LOSS_GIVEN_DEFAULT_PCT  IN_DEFAULT_FLG
# 0                   25.46               0

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7638 entries, 0 to 7637
# Columns: 175 entries, ACTIVE_CREDITS_FLG to IN_DEFAULT_FLG
# dtypes: datetime64[ns](2), float64(151), int64(9), object(13)
# memory usage: 10.2+ MB

# %%
df_train.describe()
# Out:
#        ACTIVE_CREDITS_FLG  APPLICANTS_CNT                 APPLICATION_DT  \
# count         7579.000000     7638.000000                           7638
# mean             0.684787        1.443572  2018-06-26 17:25:46.897093632
# min              0.000000        1.000000            2014-07-30 00:00:00
# 25%              0.000000        1.000000            2016-12-06 06:00:00
# 50%              1.000000        1.000000            2018-07-03 00:00:00
# 75%              1.000000        2.000000            2020-01-08 00:00:00
# max              1.000000        5.000000            2022-01-26 00:00:00
# std              0.464631        0.506237                            NaN
#
#         APPLIED_AMT  COLLATERAL_AMT  CREDIT_INTER_PRIV_PERIODIC_MTHS  \
# count  7.638000e+03    7.638000e+03                      5865.000000
# mean   3.388614e+04    6.102100e+04                         9.468883
# min    1.500000e+03    0.000000e+00                         1.000000
# 25%    1.000000e+04    0.000000e+00                        12.000000
# 50%    1.985813e+04    0.000000e+00                        12.000000
# 75%    3.200000e+04    0.000000e+00                        12.000000
# max    1.800000e+06    2.890000e+06                        12.000000
# std    6.162199e+04    2.023107e+05                         4.623966
#
#        CREDIT_INTER_PROF_PERIODIC_MTHS  DEBET_INTER_PRIV_PERIODIC_MTHS  \
# count                      4581.000000                     5865.000000
# mean                          9.483301                        9.468883
# min                           3.000000                        1.000000
# 25%                           3.000000                       12.000000
# 50%                          12.000000                       12.000000
# 75%                          12.000000                       12.000000
# max                          12.000000                       12.000000
# std                           4.039812                        4.623966
#
#        DEBET_INTER_PROF_PERIODIC_MTHS  EXP_WITH_CUSTOMER_CD  \
# count                     4581.000000           7638.000000
# mean                         9.483301              0.933752
# min                          3.000000              0.000000
# 25%                          3.000000              1.000000
# 50%                         12.000000              1.000000
# 75%                         12.000000              1.000000
# max                         12.000000              5.000000
# std                          4.039812              0.466570
#
#        EXST_CHRG_PRFCRED_AMT  KPI_CASH_FLOW_AMT  KPI_REPAYM_CAP_AMT  \
# count            7638.000000        7638.000000        7.638000e+03
# mean             5133.950922       39246.347938        1.469695e+04
# min                 0.000000           0.000000        0.000000e+00
# 25%                 0.000000       13159.495000        7.892150e+02
# 50%                 0.000000       31443.910000        7.504690e+03
# 75%              5000.000000       51432.065000        1.805756e+04
# max            270822.230000      610329.200000        4.149208e+06
# std             12379.004480       42880.096334        5.344265e+04
#
#        LOAN_TO_VALUE_PCT  LOSS_YEAR_AMT                    MATURITY_DT  \
# count        7638.000000    7638.000000                           6659
# mean           19.269127     334.877516  2024-05-26 09:11:00.099113984
# min             0.000000       0.000000            2016-01-08 00:00:00
# 25%             0.000000       0.000000            2021-08-03 00:00:00
# 50%             0.000000       0.000000            2023-10-08 00:00:00
# 75%             0.000000       0.000000            2025-11-04 12:00:00
# max          6071.428600  400507.000000            2043-11-23 00:00:00
# std            82.330585    5438.806687                            NaN
#
#        MORTGAGE_ON_REAL_ESTATE_FLG  MTHS_IN_BUSINESS_CNT  \
# count                  5839.000000             32.000000
# mean                      0.661243            232.281250
# min                       0.000000              0.000000
# 25%                       0.000000             75.250000
# 50%                       1.000000            232.500000
# 75%                       1.000000            371.250000
# max                       1.000000            668.000000
# std                       0.473328            165.901299
#
#        OTH_BANKS_CREDITS_AMT  OTHER_CREDITS_CNT  PROFIT_BEFORE_TAX_AMT  \
# count            7638.000000        7638.000000            7638.000000
# mean              349.883346           0.137863           29015.994701
# min                 0.000000           0.000000               0.000000
# 25%                 0.000000           0.000000            8252.772500
# 50%                 0.000000           0.000000           23410.980000
# 75%               352.000000           0.000000           38855.900000
# max             14804.000000           8.000000          605417.370000
# std               816.500315           0.585700           33336.279783
#
#        REAL_ESTATE_VALUE_AMT  TOT_OPEN_CREDITS_AMT  WRITE_OFF_YEAR_AMT  \
# count           1.138000e+03           7638.000000         7638.000000
# mean            3.677106e+05           5133.950922        10191.322544
# min             2.000000e+03              0.000000            0.000000
# 25%             1.300000e+05              0.000000            0.000000
# 50%             2.519257e+05              0.000000         3699.440000
# 75%             4.633250e+05           5000.000000        11533.850000
# max             2.890000e+06         270822.230000       497914.980000
# std             3.682760e+05          12379.004480        20907.370650
#
#        ANNUAL_INCOME_AMT_avg  AVG_NEG_SALDO_PRIV_12_AMT_max  \
# count            6146.000000                    5865.000000
# mean            28880.535802                     101.590899
# min               120.000000                       0.000000
# 25%             18020.820000                       0.000000
# 50%             23169.390000                       0.969444
# 75%             32203.410000                      26.239583
# max            349995.000000                    8854.578333
# std             21114.151481                     363.131532
#
#        AVG_NEG_SALDO_PRIV_1_AMT_max  AVG_NEG_SALDO_PRIV_24_AMT_max  \
# count                   5865.000000                    5865.000000
# mean                     117.927869                      96.437824
# min                        0.000000                       0.000000
# 25%                        0.000000                       0.000000
# 50%                        0.210000                       1.294375
# 75%                       23.930000                      26.703750
# max                    79532.390000                    8579.127083
# std                     1100.726834                     334.344523
#
#        AVG_NEG_SALDO_PRIV_3_AMT_max  AVG_NEG_SALDO_PRIV_6_AMT_max  \
# count                   5865.000000                   5865.000000
# mean                     109.455788                    106.412293
# min                        0.000000                      0.000000
# 25%                        0.000000                      0.000000
# 50%                        0.510000                      0.703333
# 75%                       24.460000                     26.270000
# max                    26510.796667                  13255.398333
# std                      506.609711                    406.401204
#
#        AVG_NEG_SALDO_PRIV_9_AMT_max  AVG_NEG_SALDO_PROF_12_AMT_max  \
# count                   5865.000000                    4581.000000
# mean                     103.839322                    1641.634826
# min                        0.000000                       0.000000
# 25%                        0.000000                       0.000000
# 50%                        0.844444                       0.340833
# 75%                       26.516667                     145.381667
# max                     8876.746667                  111539.587500
# std                      378.986089                    6343.584957
#
#        AVG_NEG_SALDO_PROF_1_AMT_max  AVG_NEG_SALDO_PROF_24_AMT_max  \
# count                   4581.000000                    4581.000000
# mean                    1820.665031                    1518.595372
# min                        0.000000                       0.000000
# 25%                        0.000000                       0.000000
# 50%                        0.000000                       0.711667
# 75%                      115.310000                     163.138333
# max                   124110.320000                   98604.790417
# std                     6997.986915                    5847.976116
#
#        AVG_NEG_SALDO_PROF_3_AMT_max  AVG_NEG_SALDO_PROF_6_AMT_max  \
# count                   4581.000000                   4581.000000
# mean                    1770.501369                   1719.566365
# min                        0.000000                      0.000000
# 25%                        0.000000                      0.000000
# 50%                        0.000000                      0.100000
# 75%                      129.166667                    129.070000
# max                   120393.103333                 116099.455000
# std                     6858.989258                   6683.988918
#
#        AVG_NEG_SALDO_PROF_9_AMT_max  AVG_POS_SALDO_PRIV_12_AMT_avg  \
# count                   4581.000000                    5865.000000
# mean                    1680.241372                    3198.655943
# min                        0.000000                       0.000000
# 25%                        0.000000                     373.035417
# 50%                        0.182222                    1037.506875
# 75%                      136.477778                    2565.574167
# max                   115122.616667                  248790.544444
# std                     6497.280468                    9621.496613
#
#        AVG_POS_SALDO_PRIV_1_AMT_avg  AVG_POS_SALDO_PRIV_24_AMT_avg  \
# count                   5865.000000                    5865.000000
# mean                    3318.952455                    3112.547468
# min                        0.000000                       0.000000
# 25%                      336.360000                     393.750208
# 50%                      987.330000                    1073.910638
# 75%                     2599.980000                    2652.079167
# max                   270000.000000                  300813.549167
# std                    10065.587186                    9107.032804
#
#        AVG_POS_SALDO_PRIV_3_AMT_avg  AVG_POS_SALDO_PRIV_6_AMT_avg  \
# count                   5865.000000                   5865.000000
# mean                    3298.450898                   3255.894198
# min                        0.000000                      0.000000
# 25%                      347.520000                    357.710000
# 50%                      997.368333                   1016.443333
# 75%                     2608.091667                   2576.045833
# max                   270000.000000                 259163.233333
# std                     9929.879386                   9560.954018
#
#        AVG_POS_SALDO_PRIV_9_AMT_avg  AVG_POS_SALDO_PROF_12_AMT_avg  \
# count                   5865.000000                    4581.000000
# mean                    3226.115083                    5813.226102
# min                        0.000000                       0.000000
# 25%                      367.428333                     350.010000
# 50%                     1025.195556                    1833.493333
# 75%                     2553.642222                    5808.792500
# max                   254122.636667                  221221.730000
# std                     9575.262134                   12395.502011
#
#        AVG_POS_SALDO_PROF_1_AMT_avg  AVG_POS_SALDO_PROF_24_AMT_avg  \
# count                   4581.000000                    4581.000000
# mean                    6586.866062                    5453.167904
# min                        0.000000                       0.000000
# 25%                      298.835000                     400.065000
# 50%                     1868.040000                    1819.343333
# 75%                     6516.380000                    5519.777083
# max                   184920.992000                  217682.679583
# std                    14158.620978                   11454.360315
#
#        AVG_POS_SALDO_PROF_3_AMT_avg  AVG_POS_SALDO_PROF_6_AMT_avg  \
# count                   4581.000000                   4581.000000
# mean                    6418.601942                   6170.692902
# min                        0.000000                      0.000000
# 25%                      311.313333                    328.533333
# 50%                     1835.756667                   1821.655167
# 75%                     6392.806667                   6155.563333
# max                   194967.372667                 195623.310000
# std                    13819.136382                  13174.770567
#
#        AVG_POS_SALDO_PROF_9_AMT_avg  AVG_POS_SALDO_SAVINGS_12_AMT_avg  \
# count                   4581.000000                       5399.000000
# mean                    5967.836634                      11285.345081
# min                        0.000000                          0.000000
# 25%                      335.232222                        580.507917
# 50%                     1822.987778                       3241.202500
# 75%                     5914.314444                      11779.681553
# max                   213678.750000                     970299.052500
# std                    12714.116265                      25630.812526
#
#        AVG_POS_SALDO_SAVINGS_1_AMT_avg  AVG_POS_SALDO_SAVINGS_24_AMT_avg  \
# count                      5399.000000                       5399.000000
# mean                      11585.961033                      11000.105400
# min                           0.000000                          0.000000
# 25%                         453.568000                        746.802000
# 50%                        3036.322000                       3573.879167
# 75%                       12191.077500                      11824.169719
# max                      990442.940000                     889759.804167
# std                       26264.191435                      24312.036418
#
#        AVG_POS_SALDO_SAVINGS_3_AMT_avg  AVG_POS_SALDO_SAVINGS_6_AMT_avg  \
# count                     5.399000e+03                     5.399000e+03
# mean                      1.151909e+04                     1.144056e+04
# min                       0.000000e+00                     0.000000e+00
# 25%                       4.801567e+02                     5.102300e+02
# 50%                       3.090991e+03                     3.108132e+03
# 75%                       1.226314e+04                     1.217609e+04
# max                       1.017915e+06                     1.004444e+06
# std                       2.629986e+04                     2.609928e+04
#
#        AVG_POS_SALDO_SAVINGS_9_AMT_avg  DEPENDENTS_CNT_max  \
# count                      5399.000000        6.195000e+03
# mean                      11371.397690        1.756757e+02
# min                           0.000000        0.000000e+00
# 25%                         532.511111        0.000000e+00
# 50%                        3166.848889        1.000000e+00
# 75%                       11930.190556        2.000000e+00
# max                      985906.124444        1.081998e+06
# std                       25888.553787        1.374692e+04
#
#        MONTHLY_ALIMONY_CHARGES_AMT_max  MONTHLY_CHILD_ALLOWANCE_AMT_avg  \
# count                      6317.000000                      6319.000000
# mean                          5.638431                        96.497664
# min                           0.000000                         0.000000
# 25%                           0.000000                         0.000000
# 50%                           0.000000                         0.000000
# 75%                           0.000000                       138.300000
# max                        1636.000000                      2020.600000
# std                          58.533176                       157.705277
#
#        MONTHLY_FOREIGN_INCOME_AMT_avg  MONTHLY_HOUSING_AMT_max  \
# count                     6319.000000              7638.000000
# mean                        13.047936              5133.950922
# min                          0.000000                 0.000000
# 25%                          0.000000                 0.000000
# 50%                          0.000000                 0.000000
# 75%                          0.000000              5000.000000
# max                      10000.000000            270822.230000
# std                        232.465465             12379.004480
#
#        MONTHLY_OTHER_CHARGES_AMT_max  MONTHLY_OTHER_INCOME_AMT_avg  \
# count                    6317.000000                   6319.000000
# mean                        2.205411                     88.265284
# min                         0.000000                      0.000000
# 25%                         0.000000                      0.000000
# 50%                         0.000000                      0.000000
# 75%                         0.000000                      0.000000
# max                      1300.000000                   9999.000000
# std                        36.659361                    396.225175
#
#        MONTHLY_RENTAL_CHARGES_AMT_max  MONTHLY_REPL_INCOME_AMT_avg  \
# count                     6319.000000                  6319.000000
# mean                        39.412564                    31.899410
# min                          0.000000                     0.000000
# 25%                          0.000000                     0.000000
# 50%                          0.000000                     0.000000
# 75%                          0.000000                     0.000000
# max                       2000.000000                  4573.535000
# std                        159.288905                   164.608804
#
#        MONTHS_CURRENT_ADDR_CNT_min  MONTHS_IN_BELGIUM_CNT_min  \
# count                  7615.000000                 509.000000
# mean                    158.007748                 282.713163
# min                       0.000000                   2.000000
# 25%                      58.000000                 122.000000
# 50%                     123.000000                 211.000000
# 75%                     237.000000                 444.000000
# max                     837.000000                 856.000000
# std                     127.462077                 200.792437
#
#        NO_CREDIT_CARDS_COREPRIV_CNT_max  NO_CREDIT_CARDS_COREPROF_CNT_max  \
# count                       5865.000000                       4581.000000
# mean                           0.535550                          0.204540
# min                            0.000000                          0.000000
# 25%                            0.000000                          0.000000
# 50%                            0.000000                          0.000000
# 75%                            1.000000                          0.000000
# max                            4.000000                          4.000000
# std                            0.631543                          0.457672
#
#        NO_DAYS_CRED_MIN500_PRIV_CNT_avg  NO_DAYS_CRED_MIN500_PROF_CNT_avg  \
# count                       5594.000000                       4224.000000
# mean                          46.821744                         34.300308
# min                            1.000000                          1.000000
# 25%                           17.000000                         15.000000
# 50%                           28.000000                         25.000000
# 75%                           41.000000                         35.000000
# max                          733.000000                        658.000000
# std                           79.252077                         49.896916
#
#        NO_DAYS_CRED_MIN500_SAVE_CNT_avg  NO_DAYS_DEBT_MIN500_PRIV_CNT_avg  \
# count                       4297.000000                       5520.000000
# mean                         165.539330                         56.297615
# min                            1.000000                          1.000000
# 25%                           39.000000                         19.000000
# 50%                           96.000000                         29.000000
# 75%                          237.000000                         45.000000
# max                          756.000000                        733.000000
# std                          169.266938                         93.841878
#
#        NO_DAYS_DEBT_MIN500_PROF_CNT_avg  NO_DAYS_DEBT_MIN500_SAVE_CNT_avg  \
# count                       4144.000000                       4192.000000
# mean                          34.911076                        166.752346
# min                            1.000000                          1.000000
# 25%                           15.000000                         41.000000
# 50%                           24.000000                         99.000000
# 75%                           34.000000                        239.000000
# max                          699.000000                        750.000000
# std                           56.642290                        169.672000
#
#        NO_DEBET_CARDS_COREPRIV_CNT_max  NO_DEBET_CARDS_COREPROF_CNT_max  \
# count                      5865.000000                      4581.000000
# mean                          1.854561                         1.126173
# min                           0.000000                         0.000000
# 25%                           1.000000                         1.000000
# 50%                           2.000000                         1.000000
# 75%                           2.000000                         1.000000
# max                           7.000000                        12.000000
# std                           1.057757                         0.642571
#
#        OTH_BANKS_CREDITS_AMT_max  OTHER_REAL_ESTATE_FLG_max  \
# count                7638.000000                6195.000000
# mean                  349.883346                   0.298628
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.000000
# 75%                   352.000000                   1.000000
# max                 14804.000000                   1.000000
# std                   816.500315                   0.457693
#
#        OVERDRAWN_DAYS_PRIV_1_CNT_max  OVERDRAWN_DAYS_PRIV_3_CNT_max  \
# count                    5865.000000                    5865.000000
# mean                        0.730605                       2.018926
# min                         0.000000                       0.000000
# 25%                         0.000000                       0.000000
# 50%                         0.000000                       0.000000
# 75%                         0.000000                       0.000000
# max                        40.000000                     102.000000
# std                         3.741711                       8.960472
#
#        OVERDRAWN_DAYS_PRIV_6_CNT_max  OVERDRAWN_DAYS_PRIV_9_CNT_max  \
# count                    5865.000000                    5865.000000
# mean                        3.822847                       5.455413
# min                         0.000000                       0.000000
# 25%                         0.000000                       0.000000
# 50%                         0.000000                       0.000000
# 75%                         0.000000                       0.000000
# max                       185.000000                     276.000000
# std                        15.227991                      20.727865
#
#        OVERDRAWN_DAYS_PRIV_12_CNT_max  OVERDRAWN_DAYS_PRIV_24_CNT_max  \
# count                     5865.000000                     5865.000000
# mean                         6.945610                       12.232566
# min                          0.000000                        0.000000
# 25%                          0.000000                        0.000000
# 50%                          0.000000                        0.000000
# 75%                          1.000000                        4.000000
# max                        409.000000                      654.000000
# std                         25.496641                       40.539659
#
#        OVERDRAWN_DAYS_PROF_1_CNT_max  OVERDRAWN_DAYS_PROF_3_CNT_max  \
# count                    4581.000000                    4581.000000
# mean                        0.842611                       2.193626
# min                         0.000000                       0.000000
# 25%                         0.000000                       0.000000
# 50%                         0.000000                       0.000000
# 75%                         0.000000                       0.000000
# max                        40.000000                     102.000000
# std                         4.054743                       9.658325
#
#        OVERDRAWN_DAYS_PROF_6_CNT_max  OVERDRAWN_DAYS_PROF_9_CNT_max  \
# count                    4581.000000                    4581.000000
# mean                        3.954595                       5.690242
# min                         0.000000                       0.000000
# 25%                         0.000000                       0.000000
# 50%                         0.000000                       0.000000
# 75%                         0.000000                       0.000000
# max                       184.000000                     275.000000
# std                        16.770884                      23.324058
#
#        OVERDRAWN_DAYS_PROF_12_CNT_max  OVERDRAWN_DAYS_PROF_24_CNT_max  \
# count                     4581.000000                     4581.000000
# mean                         7.466492                       13.583279
# min                          0.000000                        0.000000
# 25%                          0.000000                        0.000000
# 50%                          0.000000                        0.000000
# 75%                          0.000000                        2.000000
# max                        369.000000                      698.000000
# std                         29.691294                       50.744409
#
#        POSIT_TRANS_COREPRIV_CNT_avg  POSIT_TRANS_COREPROF_CNT_avg  \
# count                   5865.000000                   4581.000000
# mean                       7.781898                     13.755694
# min                        0.000000                      0.000000
# 25%                        2.000000                      2.000000
# 50%                        5.000000                      6.000000
# 75%                       10.000000                     14.000000
# max                      223.000000                   1216.000000
# std                       11.419182                     30.975287
#
#        POSIT_TRANS_SAVINGS_CNT_avg  SAVINGS_OPEN_CNT_max  \
# count                  5399.000000           5399.000000
# mean                      1.395166              1.760141
# min                       0.000000              1.000000
# 25%                       0.000000              1.000000
# 50%                       1.000000              1.000000
# 75%                       2.000000              2.000000
# max                     100.000000              9.000000
# std                       2.561240              1.114955
#
#        TOT_CRE_INTEREST_PRIV_1_AMT_max  TOT_CRE_INTEREST_PRIV_3_AMT_max  \
# count                      5864.000000                      5864.000000
# mean                          0.000002                         0.000005
# min                           0.000000                         0.000000
# 25%                           0.000000                         0.000000
# 50%                           0.000000                         0.000000
# 75%                           0.000000                         0.000000
# max                           0.010000                         0.030000
# std                           0.000131                         0.000392
#
#        TOT_CRE_INTEREST_PRIV_6_AMT_max  TOT_CRE_INTEREST_PRIV_9_AMT_max  \
# count                      5864.000000                      5864.000000
# mean                          0.000010                         0.000010
# min                           0.000000                         0.000000
# 25%                           0.000000                         0.000000
# 50%                           0.000000                         0.000000
# 75%                           0.000000                         0.000000
# max                           0.060000                         0.060000
# std                           0.000784                         0.000784
#
#        TOT_CRE_INTEREST_PRIV_12_AMT_max  TOT_CRE_INTEREST_PRIV_24_AMT_max  \
# count                       5864.000000                       5864.000000
# mean                           0.000031                          0.065155
# min                            0.000000                          0.000000
# 25%                            0.000000                          0.000000
# 50%                            0.000000                          0.000000
# 75%                            0.000000                          0.000000
# max                            0.180000                         56.240000
# std                            0.002351                          1.348034
#
#        TOT_CRE_INTEREST_PROF_1_AMT_max  TOT_CRE_INTEREST_PROF_3_AMT_max  \
# count                      4581.000000                      4581.000000
# mean                          0.081943                         0.542969
# min                           0.000000                         0.000000
# 25%                           0.000000                         0.000000
# 50%                           0.000000                         0.000000
# 75%                           0.000000                         0.000000
# max                         142.420000                       379.790000
# std                           2.487857                         9.895994
#
#        TOT_CRE_INTEREST_PROF_6_AMT_max  TOT_CRE_INTEREST_PROF_9_AMT_max  \
# count                      4581.000000                      4581.000000
# mean                          1.847771                         3.250009
# min                           0.000000                         0.000000
# 25%                           0.000000                         0.000000
# 50%                           0.000000                         0.000000
# 75%                           0.000000                         0.000000
# max                        1248.410000                      1825.490000
# std                          28.304068                        42.645930
#
#        TOT_CRE_INTEREST_PROF_12_AMT_max  TOT_CRE_INTEREST_PROF_24_AMT_max  \
# count                       4581.000000                       4581.000000
# mean                           4.690976                         16.821425
# min                            0.000000                          0.000000
# 25%                            0.000000                          0.000000
# 50%                            0.000000                          0.000000
# 75%                            0.000000                          0.000000
# max                         2107.480000                      12681.650000
# std                           52.358453                        214.130846
#
#        TOT_CRED_LINE_COREPRIV_AMT_max  TOT_CRED_LINE_COREPROF_AMT_max  \
# count                     5865.000000                     4581.000000
# mean                       645.975517                     4033.202868
# min                          0.000000                        0.000000
# 25%                          0.000000                        0.000000
# 50%                          0.000000                        0.000000
# 75%                       1250.000000                     2500.000000
# max                      17000.000000                   200000.000000
# std                       1087.615730                    11452.299202
#
#        TOT_DEB_INTEREST_PRIV_1_AMT_max  TOT_DEB_INTEREST_PRIV_3_AMT_max  \
# count                      5865.000000                      5865.000000
# mean                          7.172561                        21.072849
# min                           0.000000                         0.000000
# 25%                           0.000000                         0.000000
# 50%                           0.010000                         0.120000
# 75%                           1.420000                         4.800000
# max                        1286.420000                      3574.950000
# std                          35.708117                       100.863916
#
#        TOT_DEB_INTEREST_PRIV_6_AMT_max  TOT_DEB_INTEREST_PRIV_9_AMT_max  \
# count                      5865.000000                      5865.000000
# mean                         42.081154                        60.351763
# min                           0.000000                         0.000000
# 25%                           0.000000                         0.000000
# 50%                           0.300000                         0.540000
# 75%                           9.720000                        14.990000
# max                        6107.780000                      7682.260000
# std                         185.114654                       248.301855
#
#        TOT_DEB_INTEREST_PRIV_12_AMT_max  TOT_DEB_INTEREST_PRIV_24_AMT_max  \
# count                       5865.000000                       5865.000000
# mean                          77.321845                        145.758271
# min                            0.000000                          0.000000
# 25%                            0.000000                          0.000000
# 50%                            0.800000                          1.890000
# 75%                           19.920000                         39.880000
# max                         8337.000000                      16314.000000
# std                          297.649146                        551.623664
#
#        TOT_DEB_INTEREST_PROF_1_AMT_max  TOT_DEB_INTEREST_PROF_3_AMT_max  \
# count                      4581.000000                      4581.000000
# mean                        112.121015                       329.221059
# min                           0.000000                         0.000000
# 25%                           0.000000                         0.000000
# 50%                           0.000000                         0.000000
# 75%                           7.860000                        26.670000
# max                        8562.310000                     23411.640000
# std                         471.075436                      1307.052994
#
#        TOT_DEB_INTEREST_PROF_6_AMT_max  TOT_DEB_INTEREST_PROF_9_AMT_max  \
# count                      4581.000000                      4581.000000
# mean                        645.510356                       946.000622
# min                           0.000000                         0.000000
# 25%                           0.000000                         0.000000
# 50%                           0.030000                         0.120000
# 75%                          57.870000                        94.440000
# max                       39694.290000                     57665.770000
# std                        2435.574301                      3636.324641
#
#        TOT_DEB_INTEREST_PROF_12_AMT_max  TOT_DEB_INTEREST_PROF_24_AMT_max  \
# count                       4581.000000                       4581.000000
# mean                        1215.525353                       2226.843866
# min                            0.000000                          0.000000
# 25%                            0.000000                          0.000000
# 50%                            0.270000                          1.020000
# 75%                          134.330000                        255.670000
# max                        80143.610000                     145260.720000
# std                         4731.594783                       8801.137061
#
#        TOT_DOM_EXC_CRE_EXT_PRIV_AMT_max  TOT_DOM_EXC_CRE_EXT_PRIV_CNT_max  \
# count                       5865.000000                       5865.000000
# mean                         265.401497                          2.581927
# min                            0.000000                          0.000000
# 25%                            0.000000                          0.000000
# 50%                           78.330000                          1.000000
# 75%                          280.990000                          4.000000
# max                        87882.580000                         28.000000
# std                         1552.651526                          3.257924
#
#        TOT_DOM_EXC_CRE_EXT_PROF_AMT_max  TOT_DOM_EXC_CRE_EXT_PROF_CNT_max  \
# count                       4581.000000                       4581.000000
# mean                         606.246549                          2.387252
# min                            0.000000                          0.000000
# 25%                            0.000000                          0.000000
# 50%                          120.960000                          1.000000
# 75%                          501.570000                          3.000000
# max                        70711.540000                         46.000000
# std                         2360.685262                          3.589316
#
#        TOT_DOM_EXC_CRE_INT_PRIV_AMT_max  TOT_DOM_EXC_CRE_INT_PRIV_CNT_max  \
# count                               0.0                               0.0
# mean                                NaN                               NaN
# min                                 NaN                               NaN
# 25%                                 NaN                               NaN
# 50%                                 NaN                               NaN
# 75%                                 NaN                               NaN
# max                                 NaN                               NaN
# std                                 NaN                               NaN
#
#        TOT_DOM_EXC_CRE_INT_PROF_AMT_max  TOT_DOM_EXC_CRE_INT_PROF_CNT_max  \
# count                               0.0                               0.0
# mean                                NaN                               NaN
# min                                 NaN                               NaN
# 25%                                 NaN                               NaN
# 50%                                 NaN                               NaN
# 75%                                 NaN                               NaN
# max                                 NaN                               NaN
# std                                 NaN                               NaN
#
#        TOT_DOMIC_CREDCD_COREPRIV_AMT_MX  TOT_DOMIC_CREDCD_COREPROF_AMT_MX  \
# count                       1512.000000                        503.000000
# mean                         712.568538                        888.209404
# min                            0.730000                          0.010000
# 25%                          110.857500                        177.020000
# 50%                          382.695000                        493.370000
# 75%                          951.815000                       1134.520000
# max                        13365.080000                       5906.810000
# std                          989.304094                       1072.644551
#
#        TOT_OPEN_CREDITS_AMT_max  TOT_STND_PAYMENT_EXT_PRIV_AMT_MX  \
# count               7638.000000                       5865.000000
# mean                5133.950922                         95.753574
# min                    0.000000                          0.000000
# 25%                    0.000000                          0.000000
# 50%                    0.000000                          0.000000
# 75%                 5000.000000                          0.000000
# max               270822.230000                       3638.470000
# std                12379.004480                        298.632987
#
#        TOT_STND_PAYMENT_EXT_PROF_AMT_MX  TOT_STND_PAYMENT_INT_PRIV_AMT_MX  \
# count                       4581.000000                       5865.000000
# mean                         209.166169                        129.406595
# min                            0.000000                          0.000000
# 25%                            0.000000                          0.000000
# 50%                            0.000000                          0.000000
# 75%                            0.000000                          0.000000
# max                        22306.630000                      17867.920000
# std                          979.918871                        507.045149
#
#        TOT_STND_PAYMENT_INT_PROF_AMT_MX  TOT_STND_PAYMNT_EXT_PRIV_CNT_MX  \
# count                       4581.000000                      5865.000000
# mean                         258.770406                         0.381415
# min                            0.000000                         0.000000
# 25%                            0.000000                         0.000000
# 50%                            0.000000                         0.000000
# 75%                            0.000000                         0.000000
# max                        35789.500000                        23.000000
# std                         1527.584518                         0.950136
#
#        TOT_STND_PAYMNT_EXT_PROF_CNT_MX  TOT_STND_PAYMNT_INT_PRIV_CNT_MX  \
# count                      4581.000000                      5865.000000
# mean                          0.373936                         0.515431
# min                           0.000000                         0.000000
# 25%                           0.000000                         0.000000
# 50%                           0.000000                         0.000000
# 75%                           0.000000                         0.000000
# max                          31.000000                        23.000000
# std                           1.139260                         1.305021
#
#        TOT_STND_PAYMNT_INT_PROF_CNT_MX  TOTAL_EMPLOYMENT_MONTHS_CNT_min  \
# count                      4581.000000                      7607.000000
# mean                          0.352325                       143.795583
# min                           0.000000                         0.000000
# 25%                           0.000000                        56.000000
# 50%                           0.000000                       114.000000
# 75%                           0.000000                       211.000000
# max                          35.000000                       647.000000
# std                           1.404403                       111.694391
#
#        TTL_EMPLOYMENT_MONTHS_2_CNT_min  NR_APPLICANTS_WITH_INCOME  \
# count                      7612.000000                7638.000000
# mean                        144.030872                   1.378371
# min                          -1.000000                   1.000000
# 25%                          56.000000                   1.000000
# 50%                         114.000000                   1.000000
# 75%                         212.000000                   2.000000
# max                         647.000000                   3.000000
# std                         111.754622                   0.490916
#
#        BEH_SCORE_AVG_A1  BEH_SCORE_MIN_A1  BEH_SCORE_AVG_A2  BEH_SCORE_MIN_A2  \
# count       1354.000000       1354.000000        705.000000        705.000000
# mean         656.311553        642.417862        659.217787        644.780856
# min            0.000000          0.000000          0.000000          0.000000
# 25%          640.047843        623.000000        642.000000        625.000000
# 50%          662.514131        650.000000        665.867609        650.000000
# 75%          682.250857        671.956630        685.344366        675.955254
# max          729.401911        719.163223        729.401911        719.163223
# std           43.069115         47.728931         43.167825         47.893792
#
#        BEH_SCORE_AVG_A3  BEH_SCORE_MIN_A3  BEH_SCORE_AVG_AVG  \
# count          4.000000          4.000000        1372.000000
# mean         677.836341        669.509883         657.097431
# min          662.652917        646.000000           0.000000
# 25%          662.652917        646.000000         640.844564
# 50%          677.326458        669.000000         662.819889
# 75%          692.509883        692.509883         682.564040
# max          694.039531        694.039531         729.401911
# std           17.552069         27.159640          39.517593
#
#        BEH_SCORE_AVG_MIN  BEH_SCORE_MIN_AVG  BEH_SCORE_MIN_MIN    Gender_A1  \
# count        1372.000000        1372.000000        1372.000000  7604.000000
# mean          656.233263         643.327982         642.423053     1.249605
# min             0.000000           0.000000           0.000000     1.000000
# 25%           639.865846         623.709513         622.140771     1.000000
# 50%           662.564573         650.000000         650.000000     1.000000
# 75%           682.199685         673.468607         672.931363     1.000000
# max           729.401911         719.163223         719.163223     2.000000
# std            43.092065          44.702691          47.822162     0.432813
#
#          Gender_A2  Gender_A3       Nace_A1         year  birth_dt_A1  \
# count  3355.000000  25.000000   7262.000000  7638.000000  7638.000000
# mean      1.732340   1.440000  42421.890801  2017.987693  1976.478921
# min       1.000000   1.000000     11.000000  2014.000000  1940.000000
# 25%       1.000000   1.000000    472.000000  2016.000000  1968.000000
# 50%       2.000000   1.000000  43341.000000  2018.000000  1977.000000
# 75%       2.000000   2.000000  82990.000000  2020.000000  1985.000000
# max       2.000000   2.000000  99000.000000  2022.000000  2018.000000
# std       0.442805   0.506623  39002.675924     1.910148    10.995839
#
#        birth_dt_A2  birth_dt_A3  LOSS_GIVEN_DEFAULT_PCT  IN_DEFAULT_FLG
# count  3357.000000    27.000000             7638.000000     7638.000000
# mean   1974.438785  1982.000000               25.768687        0.050406
# min    1940.000000  1958.000000                6.000000        0.000000
# 25%    1966.000000  1974.000000               20.810000        0.000000
# 50%    1975.000000  1985.000000               23.220000        0.000000
# 75%    1983.000000  1989.000000               26.860000        0.000000
# max    2018.000000  2013.000000               43.000000        1.000000
# std      10.359116    13.347428                8.062319        0.218795

# %%
df_test = pd.read_excel('DSC_scoring.xlsx')
print(df_test.shape)
df_test.head(1)
# Out:
# (7637, 174)
#    ACTIVE_CREDITS_FLG  APPLICANTS_CNT APPLICATION_BY_EMPLOYEE_FLG  \
# 0                 1.0               2                           N
#
#   APPLICATION_DT  APPLIED_AMT  COLLATERAL_AMT  \
# 0     2018-01-29     490000.0             0.0
#
#    CREDIT_INTER_PRIV_PERIODIC_MTHS  CREDIT_INTER_PROF_PERIODIC_MTHS  \
# 0                             12.0                              NaN
#
#    DEBET_INTER_PRIV_PERIODIC_MTHS  DEBET_INTER_PROF_PERIODIC_MTHS  \
# 0                            12.0                             NaN
#
#    EXP_WITH_CUSTOMER_CD  EXST_CHRG_PRFCRED_AMT FINANCIAL_PRODUCT_TYPE_CD  \
# 0                     1                    0.0                       MTG
#
#    KPI_CASH_FLOW_AMT  KPI_REPAYM_CAP_AMT  LOAN_TO_VALUE_PCT  LOSS_YEAR_AMT  \
# 0           12145.57            106420.3                0.0            0.0
#
#   MATURITY_DT  MORTGAGE_ON_REAL_ESTATE_FLG  MTHS_IN_BUSINESS_CNT  \
# 0  2023-02-23                          1.0                   NaN
#
#    OTH_BANKS_CREDITS_AMT  OTHER_CREDITS_CNT  PROFIT_BEFORE_TAX_AMT  \
# 0                      0                  0               12145.57
#
#    REAL_ESTATE_VALUE_AMT  TOT_OPEN_CREDITS_AMT  WRITE_OFF_YEAR_AMT  \
# 0                    NaN                   0.0                 0.0
#
#   CREDIT_TYPE_CD  ANNUAL_INCOME_AMT_avg  AVG_NEG_SALDO_PRIV_12_AMT_max  \
# 0             IK               12753.78                            0.0
#
#    AVG_NEG_SALDO_PRIV_1_AMT_max  AVG_NEG_SALDO_PRIV_24_AMT_max  \
# 0                           0.0                            0.0
#
#    AVG_NEG_SALDO_PRIV_3_AMT_max  AVG_NEG_SALDO_PRIV_6_AMT_max  \
# 0                           0.0                           0.0
#
#    AVG_NEG_SALDO_PRIV_9_AMT_max  AVG_NEG_SALDO_PROF_12_AMT_max  \
# 0                           0.0                            NaN
#
#    AVG_NEG_SALDO_PROF_1_AMT_max  AVG_NEG_SALDO_PROF_24_AMT_max  \
# 0                           NaN                            NaN
#
#    AVG_NEG_SALDO_PROF_3_AMT_max  AVG_NEG_SALDO_PROF_6_AMT_max  \
# 0                           NaN                           NaN
#
#    AVG_NEG_SALDO_PROF_9_AMT_max  AVG_POS_SALDO_PRIV_12_AMT_avg  \
# 0                           NaN                   10025.999565
#
#    AVG_POS_SALDO_PRIV_1_AMT_avg  AVG_POS_SALDO_PRIV_24_AMT_avg  \
# 0                      29933.67                    7201.905833
#
#    AVG_POS_SALDO_PRIV_3_AMT_avg  AVG_POS_SALDO_PRIV_6_AMT_avg  \
# 0                      20690.31                  16285.215833
#
#    AVG_POS_SALDO_PRIV_9_AMT_avg  AVG_POS_SALDO_PROF_12_AMT_avg  \
# 0                  12052.084444                            NaN
#
#    AVG_POS_SALDO_PROF_1_AMT_avg  AVG_POS_SALDO_PROF_24_AMT_avg  \
# 0                           NaN                            NaN
#
#    AVG_POS_SALDO_PROF_3_AMT_avg  AVG_POS_SALDO_PROF_6_AMT_avg  \
# 0                           NaN                           NaN
#
#    AVG_POS_SALDO_PROF_9_AMT_avg  AVG_POS_SALDO_SAVINGS_12_AMT_avg  \
# 0                           NaN                      32421.838333
#
#    AVG_POS_SALDO_SAVINGS_1_AMT_avg  AVG_POS_SALDO_SAVINGS_24_AMT_avg  \
# 0                         16508.52                       24893.53625
#
#    AVG_POS_SALDO_SAVINGS_3_AMT_avg  AVG_POS_SALDO_SAVINGS_6_AMT_avg  \
# 0                         23144.93                        25940.845
#
#    AVG_POS_SALDO_SAVINGS_9_AMT_avg  DEPENDENTS_CNT_max CAT_EDUCATION_LEVEL_CD  \
# 0                     28695.327778                 0.0                    3-3
#
#   EMPLOYMENT_STATUS_CD       PROFESSION_CAT COMB_MARITAL_STATUS  \
# 0              357-401  ANDERE-ZELFSTANDIGE               02-02
#
#    MONTHLY_ALIMONY_CHARGES_AMT_max  MONTHLY_CHILD_ALLOWANCE_AMT_avg  \
# 0                              0.0                              0.0
#
#    MONTHLY_FOREIGN_INCOME_AMT_avg  MONTHLY_HOUSING_AMT_max  \
# 0                             0.0                      0.0
#
#    MONTHLY_OTHER_CHARGES_AMT_max  MONTHLY_OTHER_INCOME_AMT_avg  \
# 0                            0.0                           0.0
#
#    MONTHLY_RENTAL_CHARGES_AMT_max  MONTHLY_REPL_INCOME_AMT_avg  \
# 0                             0.0                          0.0
#
#   CAT_INCOME_SRC_CD  MONTHS_CURRENT_ADDR_CNT_min  MONTHS_IN_BELGIUM_CNT_min  \
# 0                 0                        540.0                        NaN
#
#    NO_CREDIT_CARDS_COREPRIV_CNT_max  NO_CREDIT_CARDS_COREPROF_CNT_max  \
# 0                               0.0                               NaN
#
#    NO_DAYS_CRED_MIN500_PRIV_CNT_avg  NO_DAYS_CRED_MIN500_PROF_CNT_avg  \
# 0                              21.0                               NaN
#
#    NO_DAYS_CRED_MIN500_SAVE_CNT_avg  NO_DAYS_DEBT_MIN500_PRIV_CNT_avg  \
# 0                              61.0                              21.0
#
#    NO_DAYS_DEBT_MIN500_PROF_CNT_avg  NO_DAYS_DEBT_MIN500_SAVE_CNT_avg  \
# 0                               NaN                              28.0
#
#    NO_DEBET_CARDS_COREPRIV_CNT_max  NO_DEBET_CARDS_COREPROF_CNT_max  \
# 0                              1.0                              NaN
#
#    OTH_BANKS_CREDITS_AMT_max  OTHER_REAL_ESTATE_FLG_max  \
# 0                          0                        0.0
#
#    OVERDRAWN_DAYS_PRIV_1_CNT_max  OVERDRAWN_DAYS_PRIV_3_CNT_max  \
# 0                            0.0                            0.0
#
#    OVERDRAWN_DAYS_PRIV_6_CNT_max  OVERDRAWN_DAYS_PRIV_9_CNT_max  \
# 0                            0.0                            0.0
#
#    OVERDRAWN_DAYS_PRIV_12_CNT_max  OVERDRAWN_DAYS_PRIV_24_CNT_max  \
# 0                             0.0                             0.0
#
#    OVERDRAWN_DAYS_PROF_1_CNT_max  OVERDRAWN_DAYS_PROF_3_CNT_max  \
# 0                            NaN                            NaN
#
#    OVERDRAWN_DAYS_PROF_6_CNT_max  OVERDRAWN_DAYS_PROF_9_CNT_max  \
# 0                            NaN                            NaN
#
#    OVERDRAWN_DAYS_PROF_12_CNT_max  OVERDRAWN_DAYS_PROF_24_CNT_max  \
# 0                             NaN                             NaN
#
#    POSIT_TRANS_COREPRIV_CNT_avg  POSIT_TRANS_COREPROF_CNT_avg  \
# 0                           5.0                           NaN
#
#    POSIT_TRANS_SAVINGS_CNT_avg CAT_REP_INCOME_SRC_CD CAT_RESIDENT_STATUS_CD  \
# 0                          1.0                   NaN                      1
#
#    SAVINGS_OPEN_CNT_max  TOT_CRE_INTEREST_PRIV_1_AMT_max  \
# 0                   1.0                              0.0
#
#    TOT_CRE_INTEREST_PRIV_3_AMT_max  TOT_CRE_INTEREST_PRIV_6_AMT_max  \
# 0                              0.0                              0.0
#
#    TOT_CRE_INTEREST_PRIV_9_AMT_max  TOT_CRE_INTEREST_PRIV_12_AMT_max  \
# 0                              0.0                               0.0
#
#    TOT_CRE_INTEREST_PRIV_24_AMT_max  TOT_CRE_INTEREST_PROF_1_AMT_max  \
# 0                               0.0                              NaN
#
#    TOT_CRE_INTEREST_PROF_3_AMT_max  TOT_CRE_INTEREST_PROF_6_AMT_max  \
# 0                              NaN                              NaN
#
#    TOT_CRE_INTEREST_PROF_9_AMT_max  TOT_CRE_INTEREST_PROF_12_AMT_max  \
# 0                              NaN                               NaN
#
#    TOT_CRE_INTEREST_PROF_24_AMT_max  TOT_CRED_LINE_COREPRIV_AMT_max  \
# 0                               NaN                             0.0
#
#    TOT_CRED_LINE_COREPROF_AMT_max  TOT_DEB_INTEREST_PRIV_1_AMT_max  \
# 0                             NaN                              0.0
#
#    TOT_DEB_INTEREST_PRIV_3_AMT_max  TOT_DEB_INTEREST_PRIV_6_AMT_max  \
# 0                              0.0                              0.0
#
#    TOT_DEB_INTEREST_PRIV_9_AMT_max  TOT_DEB_INTEREST_PRIV_12_AMT_max  \
# 0                              0.0                               0.0
#
#    TOT_DEB_INTEREST_PRIV_24_AMT_max  TOT_DEB_INTEREST_PROF_1_AMT_max  \
# 0                               0.0                              NaN
#
#    TOT_DEB_INTEREST_PROF_3_AMT_max  TOT_DEB_INTEREST_PROF_6_AMT_max  \
# 0                              NaN                              NaN
#
#    TOT_DEB_INTEREST_PROF_9_AMT_max  TOT_DEB_INTEREST_PROF_12_AMT_max  \
# 0                              NaN                               NaN
#
#    TOT_DEB_INTEREST_PROF_24_AMT_max  TOT_DOM_EXC_CRE_EXT_PRIV_AMT_max  \
# 0                               NaN                               0.0
#
#    TOT_DOM_EXC_CRE_EXT_PRIV_CNT_max  TOT_DOM_EXC_CRE_EXT_PROF_AMT_max  \
# 0                               0.0                               NaN
#
#    TOT_DOM_EXC_CRE_EXT_PROF_CNT_max  TOT_DOM_EXC_CRE_INT_PRIV_AMT_max  \
# 0                               NaN                               NaN
#
#    TOT_DOM_EXC_CRE_INT_PRIV_CNT_max  TOT_DOM_EXC_CRE_INT_PROF_AMT_max  \
# 0                               NaN                               NaN
#
#    TOT_DOM_EXC_CRE_INT_PROF_CNT_max  TOT_DOMIC_CREDCD_COREPRIV_AMT_MX  \
# 0                               NaN                               NaN
#
#    TOT_DOMIC_CREDCD_COREPROF_AMT_MX  TOT_OPEN_CREDITS_AMT_max  \
# 0                               NaN                       0.0
#
#    TOT_STND_PAYMENT_EXT_PRIV_AMT_MX  TOT_STND_PAYMENT_EXT_PROF_AMT_MX  \
# 0                               0.0                               NaN
#
#    TOT_STND_PAYMENT_INT_PRIV_AMT_MX  TOT_STND_PAYMENT_INT_PROF_AMT_MX  \
# 0                               0.0                               NaN
#
#    TOT_STND_PAYMNT_EXT_PRIV_CNT_MX  TOT_STND_PAYMNT_EXT_PROF_CNT_MX  \
# 0                              0.0                              NaN
#
#    TOT_STND_PAYMNT_INT_PRIV_CNT_MX  TOT_STND_PAYMNT_INT_PROF_CNT_MX  \
# 0                              0.0                              NaN
#
#    TOTAL_EMPLOYMENT_MONTHS_CNT_min  TTL_EMPLOYMENT_MONTHS_2_CNT_min  \
# 0                            216.0                            217.0
#
#    NR_APPLICANTS_WITH_INCOME  BEH_SCORE_AVG_A1  BEH_SCORE_MIN_A1  \
# 0                          1               NaN               NaN
#
#    BEH_SCORE_AVG_A2  BEH_SCORE_MIN_A2  BEH_SCORE_AVG_A3  BEH_SCORE_MIN_A3  \
# 0               NaN               NaN               NaN               NaN
#
#    BEH_SCORE_AVG_AVG  BEH_SCORE_AVG_MIN  BEH_SCORE_MIN_AVG  BEH_SCORE_MIN_MIN  \
# 0                NaN                NaN                NaN                NaN
#
#    Gender_A1  Gender_A2  Gender_A3 nationality_A1 nationality_A2  \
# 0        1.0        2.0        NaN              B              B
#
#   nationality_A3  Nace_A1  year  birth_dt_A1  birth_dt_A2  birth_dt_A3  \
# 0            NaN     11.0  2018         1970       1978.0          NaN
#
#    LOSS_GIVEN_DEFAULT_PCT
# 0                   20.81

# %%
df_labels = pd.read_excel('DSC_labels_info.xlsx')
print(df_labels.shape)
df_labels.head(1)
# Out:
# (175, 3)
#              Name       Type         Label
# 0  IN_DEFAULT_FLG  Character  Default Flag
